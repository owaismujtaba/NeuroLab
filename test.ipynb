# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
audio = np.load('Data\P01_audio.npy')
audio.shape
# Out:
# (14414532,)

# %%
seeg = np.load('Data\P01_sEEG.npy')
seeg.shape
# Out:
# (307511, 130)

# %%
plt.plot(audio[30000:60000])

# %%
sample = seeg[1024:8000]
sample = np.mean(sample, axis=1)
sample.shape
plt.plot(sample)

# %%
seeg.shape
# Out:
# (307511, 130)
